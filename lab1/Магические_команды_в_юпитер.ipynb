# %%
# %lsmagic

# %time sum(range(1000000))
# %timeit sum(range(1000000))

# ЭТИ СТРОЧКИ КОДА Я ПИСАЛ В АУДИТОРИИ, НЕ МОГ ЗАПУСТИТЬ ЮПИТЕР, НО ОНИ РАБОЧИЕ
# %%writefile proga_test.py
# f = lambda x: x ** 2
# print(f(5))

# !python proga_text.py

# %ls
# %history
# Out:
# program1  sample_data/
# import os
#
# with open("file.txt", "w") as f:
#   f.write("Я ")
#   f.write("люблю ")
#   f.write("когда\n")
#   f.write("шумят березы")
# import os
#
# with open("file.txt", "w") as f:
#   f.write("Я ")
#   f.write("люблю ")
#   f.write("когда\n")
#   f.write("шумят березы")
#
# with open("file.txt", "r") as f:
#   content = f.readlines()
#   print("Содержимое файла:\n", content)
# # # Проверка существования файла
# # print("Файл существует:", os.path.exists("example.txt"))
# # # Удаление файла
# # os.remove("example.txt")
# # print("Файл удален.")
# import os
#
# with open("file.txt", "w") as f:
#   f.write("Я ")
#   f.write("люблю ")
#   f.write("когда\n")
#   f.write("шумят березы")
#
# with open("file.txt", "r") as f:
#   content = f.readlines()
#   print("Содержимое файла:\n", *content)
# # # Проверка существования файла
# # print("Файл существует:", os.path.exists("example.txt"))
# # # Удаление файла
# # os.remove("example.txt")
# ...
